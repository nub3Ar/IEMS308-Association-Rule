# %%
import warnings
warnings.filterwarnings('ignore')

import dask.dataframe as dd
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from pandas_profiling import ProfileReport as PR

# %%
data_path = '/mnt/c/Course Data/Dillards_POS/'
file_name = ['deptinfo.csv', 'strinfo.csv', 'skuinfo.csv', 'trnsact.csv', 'skstinfo.csv']

# %%
transaction = dd.read_csv(data_path+file_name[3], header = None)
sksinfo = dd.read_csv(data_path+file_name[4], header = None)

# %%
deptinfo = pd.read_csv(data_path+file_name[0], header = None)
strinfo = pd.read_csv(data_path+file_name[1], header = None)
skuinfo = pd.read_csv(data_path+file_name[2], error_bad_lines=False, header=None)
# Out:
# b'Skipping line 92: expected 11 fields, saw 12\nSkipping line 93: expected 11 fields, saw 12\nSkipping line 178: expected 11 fields, saw 12\nSkipping line 180: expected 11 fields, saw 12\nSkipping line 183: expected 11 fields, saw 12\nSkipping line 195: expected 11 fields, saw 12\nSkipping line 233: expected 11 fields, saw 12\nSkipping line 591: expected 11 fields, saw 12\nSkipping line 610: expected 11 fields, saw 12\nSkipping line 830: expected 11 fields, saw 12\nSkipping line 1348: expected 11 fields, saw 12\nSkipping line 1471: expected 11 fields, saw 12\nSkipping line 1509: expected 11 fields, saw 12\nSkipping line 1639: expected 11 fields, saw 12\nSkipping line 1728: expected 11 fields, saw 12\nSkipping line 1753: expected 11 fields, saw 12\nSkipping line 1774: expected 11 fields, saw 12\nSkipping line 2156: expected 11 fields, saw 12\nSkipping line 2181: expected 11 fields, saw 12\nSkipping line 2505: expected 11 fields, saw 12\nSkipping line 2727: expected 11 fields, saw 12\n
# ...
